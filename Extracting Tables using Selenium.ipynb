# %%
from selenium import webdriver
import pandas as pd

# %%
Path = 'C:\\Users\\User\\Desktop\\chromedriver.exe'
url = 'https://www.w3schools.com/sql/trysql.asp?filename=trysql_select_all'

# %%
driver = webdriver.Chrome(Path)
driver.get(url)

# %%
Data = driver.find_element_by_css_selector('#restoreDBBtn')
Data.click()

# %%
object = driver.switch_to.alert
object.accept()

# %%
Table = driver.find_element_by_css_selector('#yourDB > table > tbody > tr:nth-child(9) > td:nth-child(1)')
Table.click()

# %%
Attr = driver.find_element_by_css_selector('#divResultSQL > div > table').get_attribute('outerHTML')

# %%
All_Tables = pd.read_html(Attr,header= 0)

# %%
All_Tables[0]
# Out:
#     SupplierID                            SupplierName  \
# 0            1                           Exotic Liquid
# 1            2              New Orleans Cajun Delights
# 2            3               Grandma Kelly's Homestead
# 3            4                           Tokyo Traders
# 4            5      Cooperativa de Quesos 'Las Cabras'
# 5            6                                Mayumi's
# 6            7                           Pavlova, Ltd.
# 7            8                Specialty Biscuits, Ltd.
# 8            9                        PB Knäckebröd AB
# 9           10               Refrescos Americanas LTDA
# 10          11             Heli Süßwaren GmbH & Co. KG
# 11          12       Plutzer Lebensmittelgroßmärkte AG
# 12          13  Nord-Ost-Fisch Handelsgesellschaft mbH
# 13          14                 Formaggi Fortini s.r.l.
# 14          15                         Norske Meierier
# 15          16                       Bigfoot Breweries
# ...

# %%
df = All_Tables[0]

# %%
df.columns
# Out:
# Index(['SupplierID', 'SupplierName', 'ContactName', 'Address', 'City',
#        'PostalCode', 'Country', 'Phone'],
#       dtype='object')

# %%
df.to_csv(r'C:\Users\User\Documents\SUPPLIERS.csv', index = False, header = True)
